# %%
import numpy as np
import pandas as pd
from warnings import filterwarnings
filterwarnings("ignore")

# %%
df = pd.read_csv("cereals_data.csv")
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100%_Bran   N    C        70        4    1     130   10.0
# 1           100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 4              Almond_Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat_Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties_Honey_Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
#1. Describe the schema of table 
df.describe(include='all')
# Out:
#              name  mfr type    calories    protein        fat      sodium  \
# count          77   77   77   77.000000  77.000000  77.000000   77.000000
# unique         77    7    2         NaN        NaN        NaN         NaN
# top     100%_Bran    K    C         NaN        NaN        NaN         NaN
# freq            1   23   74         NaN        NaN        NaN         NaN
# mean          NaN  NaN  NaN  106.883117   2.545455   1.012987  159.675325
# std           NaN  NaN  NaN   19.484119   1.094790   1.006473   83.832295
# min           NaN  NaN  NaN   50.000000   1.000000   0.000000    0.000000
# 25%           NaN  NaN  NaN  100.000000   2.000000   0.000000  130.000000
# 50%           NaN  NaN  NaN  110.000000   3.000000   1.000000  180.000000
# 75%           NaN  NaN  NaN  110.000000   3.000000   2.000000  210.000000
# max           NaN  NaN  NaN  160.000000   6.000000   5.000000  320.000000
#
#             fiber      carbo     sugars      potass    vitamins      shelf  \
# ...

# %%
#2. Create view name as see where users can not see type column [first run appropriate query then create view] 
see = df.copy()
see
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100%_Bran   N    C        70        4    1     130   10.0
# 1           100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 4              Almond_Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat_Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties_Honey_Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
see.drop('type',axis=1,inplace=True)
see
# Out:
#                          name mfr  calories  protein  fat  sodium  fiber  \
# 0                   100%_Bran   N        70        4    1     130   10.0
# 1           100%_Natural_Bran   Q       120        3    5      15    2.0
# 2                    All-Bran   K        70        4    1     260    9.0
# 3   All-Bran_with_Extra_Fiber   K        50        4    0     140   14.0
# 4              Almond_Delight   R       110        2    2     200    1.0
# ..                        ...  ..       ...      ...  ...     ...    ...
# 72                    Triples   G       110        2    1     250    0.0
# 73                       Trix   G       110        1    1     140    0.0
# 74                 Wheat_Chex   R       100        3    1     230    3.0
# 75                   Wheaties   G       100        3    1     200    3.0
# 76        Wheaties_Honey_Gold   G       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# ...

# %%
#3. Rename the view as saw 
saw = see.copy(deep=True)
saw
# Out:
#                          name mfr  calories  protein  fat  sodium  fiber  \
# 0                   100%_Bran   N        70        4    1     130   10.0
# 1           100%_Natural_Bran   Q       120        3    5      15    2.0
# 2                    All-Bran   K        70        4    1     260    9.0
# 3   All-Bran_with_Extra_Fiber   K        50        4    0     140   14.0
# 4              Almond_Delight   R       110        2    2     200    1.0
# ..                        ...  ..       ...      ...  ...     ...    ...
# 72                    Triples   G       110        2    1     250    0.0
# 73                       Trix   G       110        1    1     140    0.0
# 74                 Wheat_Chex   R       100        3    1     230    3.0
# 75                   Wheaties   G       100        3    1     200    3.0
# 76        Wheaties_Honey_Gold   G       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# ...

# %%
#4. Count how many are cold cereals 
df['type'][df['type']=='C'].value_counts()
# Out:
# type
# C    74
# Name: count, dtype: int64

# %%
#5. Count how many cereals are kept in shelf 3 
df['shelf'][df['shelf']==3].value_counts()
# Out:
# shelf
# 3    36
# Name: count, dtype: int64

# %%
#6. Arrange the table from high to low according to ratings 
df1 = df.copy(deep = True)
df2 = df1.sort_values('rating',ascending=False)
df2
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 3   All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 64     Shredded_Wheat_'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded_Wheat_spoon_size   N    C        90        3    0       0    3.0
# 0                   100%_Bran   N    C        70        4    1     130   10.0
# 63             Shredded_Wheat   N    C        80        2    0       0    3.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 14                Cocoa_Puffs   G    C       110        1    1     180    0.0
# 18              Count_Chocula   G    C       110        1    1     180    0.0
# 35           Honey_Graham_Ohs   Q    C       120        1    2     220    1.0
# 12      Cinnamon_Toast_Crunch   G    C       120        1    3     210    0.0
# 10               Cap'n'Crunch   Q    C       120        1    2     220    0.0
#
# ...

# %%
#7. Suggest some column/s which can be Primary key 
df.isnull().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       1
# sugars      1
# potass      2
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
df.nunique()
# Out:
# name        77
# mfr          7
# type         2
# calories    11
# protein      6
# fat          5
# sodium      27
# fiber       13
# carbo       21
# sugars      16
# potass      35
# vitamins     3
# shelf        3
# weight       7
# cups        12
# rating      77
# dtype: int64

# %% [markdown]
# Therefore name or rating can be used as a primary key.

# %%
#8. Find average of calories of hot cereal and cold cereal in one query 
df.groupby('type').calories.mean()
# Out:
# type
# C    107.162162
# H    100.000000
# Name: calories, dtype: float64

# %%
#9. List only those cereals whose name begins with B 
df[df.name.str.startswith('B')]
# Out:
#           name mfr type  calories  protein  fat  sodium  fiber  carbo  sugars  \
# 7      Basic_4   G    C       130        3    2     210    2.0   18.0     8.0
# 8    Bran_Chex   R    C        90        2    1     200    4.0   15.0     6.0
# 9  Bran_Flakes   P    C        90        3    0     210    5.0   13.0     5.0
#
#    potass  vitamins  shelf  weight  cups     rating
# 7   100.0        25      3    1.33  0.75  37.038562
# 8   125.0        25      1    1.00  0.67  49.120253
# 9   190.0        25      3    1.00  0.67  53.313813

# %%
#10. List only those cereals whose name begins with F 
df[df.name.str.startswith('F')]
# Out:
#                                       name mfr type  calories  protein  fat  \
# 24                             Froot_Loops   K    C       110        2    1
# 25                          Frosted_Flakes   K    C       110        1    0
# 26                     Frosted_Mini-Wheats   K    C       100        3    0
# 27  Fruit_&_Fibre_Dates,_Walnuts,_and_Oats   P    C       120        3    2
# 28                           Fruitful_Bran   K    C       120        3    0
# 29                          Fruity_Pebbles   P    C       110        1    1
#
#     sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# 24     125    1.0   11.0    13.0    30.0        25      2    1.00  1.00
# 25     200    1.0   14.0    11.0    25.0        25      1    1.00  0.75
# 26       0    3.0   14.0     7.0   100.0        25      2    1.00  0.80
# 27     160    5.0   12.0    10.0   200.0        25      3    1.25  0.67
# 28     240    5.0   14.0    12.0   190.0        25      3    1.33  0.67
# ...

# %%
#11. List only those cereals whose name ends with s 
df[df.name.str.endswith('s')]
# Out:
#                                       name mfr type  calories  protein  fat  \
# 5                  Apple_Cinnamon_Cheerios   G    C       110        2    2
# 6                              Apple_Jacks   K    C       110        2    0
# 9                              Bran_Flakes   P    C        90        3    0
# 11                                Cheerios   G    C       110        6    2
# 13                                Clusters   G    C       110        3    2
# 14                             Cocoa_Puffs   G    C       110        1    1
# 16                             Corn_Flakes   K    C       100        2    0
# 17                               Corn_Pops   K    C       110        1    0
# 22                  Crispy_Wheat_&_Raisins   G    C       100        2    1
# 24                             Froot_Loops   K    C       110        2    1
# 25                          Frosted_Flakes   K    C       110        1    0
# ...

# %%
#12. Find maximum of ratings
df.rating.max()
# Out:
# 93.704912

# %%
#13. Remove column fat 
df1.drop('fat',axis=1,inplace=True)
df1
# Out:
#                          name mfr type  calories  protein  sodium  fiber  \
# 0                   100%_Bran   N    C        70        4     130   10.0
# 1           100%_Natural_Bran   Q    C       120        3      15    2.0
# 2                    All-Bran   K    C        70        4     260    9.0
# 3   All-Bran_with_Extra_Fiber   K    C        50        4     140   14.0
# 4              Almond_Delight   R    C       110        2     200    1.0
# ..                        ...  ..  ...       ...      ...     ...    ...
# 72                    Triples   G    C       110        2     250    0.0
# 73                       Trix   G    C       110        1     140    0.0
# 74                 Wheat_Chex   R    C       100        3     230    3.0
# 75                   Wheaties   G    C       100        3     200    3.0
# 76        Wheaties_Honey_Gold   G    C       110        2     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# ...

# %%
#17. Count records for each manufacturer [mfr] 
df.groupby('mfr').mfr.value_counts()
# Out:
# mfr
# A     1
# G    22
# K    23
# N     6
# P     9
# Q     8
# R     8
# Name: count, dtype: int64

# %%
#18. Select name, calories and ratings only
df[['name','calories','rating']]
# Out:
#                          name  calories     rating
# 0                   100%_Bran        70  68.402973
# 1           100%_Natural_Bran       120  33.983679
# 2                    All-Bran        70  59.425505
# 3   All-Bran_with_Extra_Fiber        50  93.704912
# 4              Almond_Delight       110  34.384843
# ..                        ...       ...        ...
# 72                    Triples       110  39.106174
# 73                       Trix       110  27.753301
# 74                 Wheat_Chex       100  49.787445
# 75                   Wheaties       100  51.592193
# 76        Wheaties_Honey_Gold       110  36.187559
#
# [77 rows x 3 columns]
